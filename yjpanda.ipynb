# %%
import numpy as np

# %%
import pandas as pd

s = pd.Series([10, 20, 30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s=pd.Series([10,20,30],index=['yash','arjun','nikhil'])

# %%
s
# Out:
# yash      10
# arjun     20
# nikhil    30
# dtype: int64

# %%
d={'a':1,'b':2,'c':3}

# %%
s=pd.Series(d)

# %%
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
x=[1,2,3,4]
y=['Yash','Nikhil','Chaman','Divs']

# %%
z=pd.Series(data=x,index=y)

# %%
z
# Out:
# Yash      1
# Nikhil    2
# Chaman    3
# Divs      4
# dtype: int64

# %% [markdown]
# starting of PANDAS

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df=pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.shape
# Out:
# (5, 4)

# %%
df.sum(axis=0)
# Out:
# W    1.719289
# X    2.268822
# Y    2.261436
# Z    2.159356
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# A    4.746778
# B    0.089688
# C   -1.338233
# D   -0.548357
# E    5.459028
# dtype: float64

# %%
data={'Name':['Yash','Subhrata','Aanya'],'Age':[30,31,28]}
ydf=pd.DataFrame(data)

# %%
ydf
# Out:
#        Name  Age
# 0      Yash   30
# 1  Subhrata   31
# 2     Aanya   28

# %%
jdf = pd.DataFrame(np.arange(1,10).reshape(3,3),
                  index=['A','B','C'],
                  columns=['X','Y','Z'])

# %%
jdf
# Out:
#    X  Y  Z
# A  1  2  3
# B  4  5  6
# C  7  8  9

# %%
jdf.sum(axis=0)
# Out:
# X    12
# Y    15
# Z    18
# dtype: int64

# %%
jdf.sum(axis=1)
# Out:
# A     6
# B    15
# C    24
# dtype: int64

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
